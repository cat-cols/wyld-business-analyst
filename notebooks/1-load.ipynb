# %% [markdown]
# <details>
# <summary>spin up your local server</summary>
#
# Yep — I can’t spin up your local Postgres server from here, but I **did create a PostgreSQL-ready version** of the simulated Wyld database for you (schema + load scripts + CSVs).
#
# ### Download
#
# * [wyld_postgres_bundle.zip](sandbox:/mnt/data/wyld_postgres_bundle.zip)
#
# ### What’s inside
#
# * `01_create_wyld_sim_postgres.sql` — creates all dimension/fact tables + indexes
# * `02_load_wyld_sim_postgres.sql` — loads the data via `\copy`
# * `README_POSTGRES.md` — quick start
# * CSVs for every table (`fact_sales.csv`, `dim_date.csv`, etc.)
#
# ### How to run (locally)
#
# ```bash
# createdb wyld_sim
# psql -d wyld_sim -f 01_create_wyld_sim_postgres.sql
# psql -d wyld_sim -f 02_load_wyld_sim_postgres.sql
# ```
#
# This gives you a real Postgres sandbox to run your Wyld BA queries against. Very nice for portfolio screenshots too — “simulated warehouse in PostgreSQL” sounds way more serious than “I had a spreadsheet and vibes.”
#
# </details>

# %%
# Create database
createdb wyld_sim
psql -d wyld_sim -f 01_create_wyld_sim_postgres.sql
psql -d wyld_sim -f 02_load_wyld_sim_postgres.sql
